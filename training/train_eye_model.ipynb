# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import layers, models

train_dir = "dataset"

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)

train_data = datagen.flow_from_directory(
    train_dir, target_size=(96,96), batch_size=32,
    class_mode='binary', subset='training'
)
val_data = datagen.flow_from_directory(
    train_dir, target_size=(96,96), batch_size=32,
    class_mode='binary', subset='validation'
)

base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(96,96,3))
base_model.trainable = False  # freeze convolutional base

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(train_data, validation_data=val_data, epochs=10)

loss, acc = model.evaluate(val_data)
print(f"✅ Validation Accuracy: {acc*100:.2f}%")

model.save("eye_model_mobilenet.h5")

# Convert to TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()
open("eye_model_mobilenet.tflite", "wb").write(tflite_model)
# Out:
# Found 996 images belonging to 2 classes.
# Found 249 images belonging to 2 classes.
# C:\Users\Prathima B A\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 564ms/step - accuracy: 0.7300 - loss: 0.5626 - val_accuracy: 0.5823 - val_loss: 0.6698
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 438ms/step - accuracy: 0.9059 - loss: 0.2472 - val_accuracy: 0.8193 - val_loss: 0.4266
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 426ms/step - accuracy: 0.9068 - loss: 0.2100 - val_accuracy: 0.7831 - val_loss: 0.4121
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 428ms/step - accuracy: 0.9451 - loss: 0.1511 - val_accuracy: 0.7510 - val_loss: 0.4208
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 430ms/step - accuracy: 0.9596 - loss: 0.1308 - val_accuracy: 0.7229 - val_loss: 0.4813
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 415ms/step - accuracy: 0.9481 - loss: 0.1270 - val_accuracy: 0.7108 - val_loss: 0.5248
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 435ms/step - accuracy: 0.9643 - loss: 0.1158 - val_accuracy: 0.8675 - val_loss: 0.2882
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 426ms/step - accuracy: 0.9607 - loss: 0.1086 - val_accuracy: 0.7269 - val_loss: 0.5230
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 436ms/step - accuracy: 0.9499 - loss: 0.1311 - val_accuracy: 0.7590 - val_loss: 0.4919
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 417ms/step - accuracy: 0.9608 - loss: 0.0975 - val_accuracy: 0.8032 - val_loss: 0.4160
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 316ms/step - accuracy: 0.8258 - loss: 0.3255
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Validation Accuracy: 82.33%
# INFO:tensorflow:Assets written to: C:\Users\PRATHI~1\AppData\Local\Temp\tmpz0cue2qh\assets
# INFO:tensorflow:Assets written to: C:\Users\PRATHI~1\AppData\Local\Temp\tmpz0cue2qh\assets
# Saved artifact at 'C:\Users\PRATHI~1\AppData\Local\Temp\tmpz0cue2qh'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 96, 96, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   3075356651600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075356652176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075356654096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075356653712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075356652560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075356654288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075356653328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075356651024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075356654480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075356652368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075356654864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358229520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358228560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075356652752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358228752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358231248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358233168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358231824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358232208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358231056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358234704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358234320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358233936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358234896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358233552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358237008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358237392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358237776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358237584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358232400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358238928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358239312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358239696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358239504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358235856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358240848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358241232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358241616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358241424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358236624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358238544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358243344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358243728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358243536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358240080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358242768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358556816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358557200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358244496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358242384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358558352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358558736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358559120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358558928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358556240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358560272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358560656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358561040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358560848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358556624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358562192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358562576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358562960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358562768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358557968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358564112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358564496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358564880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358564688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358559888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358566032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358566416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358566800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358566608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358561808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358567952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358568336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358568720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358568528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358563728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358569872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358570256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358570640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358570448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358565648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358571792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358572368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358571024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358572176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075358569488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375546640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375547984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375548368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375548176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375546832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375549520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375549904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375550288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375550096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375547408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375551440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375551824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375552208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375552016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375547600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375553360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375553744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375554128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375553936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375549136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375555280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375555664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375556048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375555856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375551056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375557200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375557584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375557968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375557776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375552976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375559120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375559504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375559888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375559696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375554896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375561040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375561424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375561808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375561616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375556816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375560272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375907472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375907856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375562576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375558736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375909008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375909392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375909776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375909584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375906896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375910928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375911312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375911696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375911504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375907280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375912848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375913232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375913616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375913424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375908624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375914768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375915152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375915536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375915344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375910544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375916688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375917072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375917456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375917264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375912464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375918608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375918992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375919376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375919184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375914384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375920528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375920912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375921296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375921104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375916304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375922448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375923024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375921680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375922832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075375920144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376267536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376268880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376269264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376269072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376267728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376270416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376270800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376271184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376270992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376268304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376272336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376272720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376273104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376272912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376268496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376274256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376274640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376275024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376274832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376270032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376276176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376276560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376276944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376276752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376271952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376278096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376278480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376278864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376278672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376273872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376280016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376280400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376280784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376280592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376275792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376281936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376282320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376282704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376282512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376277712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376281168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376726672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376726096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376283472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376279632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376728208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376727056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376728976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376728784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075356651408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376726288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376730512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376730896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376730704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376726864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376732048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376732432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376732816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376732624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376729552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376733968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376734352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376734736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376734544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376730128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376735888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376736272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376736656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376736464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376731664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376737808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376738192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376738576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376738384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376733584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376739728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376740112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376740496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376740304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376735504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376741648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376742224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376740880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376742032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075376739344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075377251728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075377253264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075377252688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3075377254032: TensorSpec(shape=(), dtype=tf.resource, name=None)
# 2589080
